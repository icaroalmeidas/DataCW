# %%
#Importando as bibliotecas necessárias
import pandas as pd
import numpy as np

# %% [markdown]
# ### Leitura de planilha

# %%
path = "H:/Meu Drive/PESSOAL/PROJETOS/DataCW/Datasets/athletes.csv"

# %%
pd.read_csv(path)
# Out:
#           code                        name     name_short  \
# 0      1532872            ALEKSANYAN Artur   ALEKSANYAN A
# 1      1532873              AMOYAN Malkhas       AMOYAN M
# 2      1532874             GALSTYAN Slavik     GALSTYAN S
# 3      1532944           HARUTYUNYAN Arsen  HARUTYUNYAN A
# 4      1532945             TEVANYAN Vazgen     TEVANYAN V
# ...        ...                         ...            ...
# 11105  4982175               JOSEPH Elijah       JOSEPH E
# 11106  4982762             HOMAN Khrystyna        HOMAN K
# 11107  4983537  CHELANGAT Annet Chemengich   CHELANGAT AC
# 11108  4986655              ADA ETO Sefora      ADA ETO S
# 11109  9460001             LIUZZI Emanuela       LIUZZI E
#
#                           name_tv  gender function country_code  \
# 0                Artur ALEKSANYAN    Male  Athlete          ARM
# 1                  Malkhas AMOYAN    Male  Athlete          ARM
# 2                 Slavik GALSTYAN    Male  Athlete          ARM
# ...
